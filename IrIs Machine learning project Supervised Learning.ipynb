# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe().plot(kind = 'area',fontsize = 15,figsize = (15,8),table = True,colormap="rainbow")
plt.grid()
plt.xlabel('Statistics')
plt.ylabel('value')
plt.show()

# %%
sns.countplot(df['Species'],data = df)
plt.show()

# %%
df['Species'].value_counts().plot.pie(explode = [0.1,0.1,0.1],autopct = '%1.1f%%',shadow = True,figsize = (15,8))
plt.show()

# %%
sns.jointplot(x = 'SepalLengthCm',y ='SepalWidthCm',data = df )

plt.show()

# %%
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=df, kind="reg")
plt.show()

# %%
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=df, kind="kde",space=0,color='g')
plt.show()

# %%
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=df, kind="hex")
plt.show()

# %%
g = (sns.jointplot("SepalLengthCm", "SepalWidthCm",data=df, color="k").plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(x='Species',y='PetalLengthCm',data = df,order = ['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth = 2.5,orient = 'v',dodge = False)
fig.grid()

# %%
df.boxplot(by = 'Species',figsize =(15,10))
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
sns.stripplot(x = 'Species',y = 'SepalLengthCm',data = df,jitter = True,edgecolor = 'gray',size=8,palette= 'winter',orient = 'v')
plt.show()

# %%
sns.set(style="darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(x = 'Species',y = 'SepalLengthCm',data = df)
fig = sns.stripplot(x = 'Species',y = 'SepalLengthCm',data = df,jitter = True)

# %%
sns.set(style="darkgrid")
ax = sns.boxplot(x = 'Species',y ='SepalLengthCm',data = df)
ax = sns.stripplot(x = 'Species', y= 'SepalLengthCm',data = df,jitter = True, edgecolor="gray")
boxtwo = ax.artists[2]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree = ax.artists[0]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')
boxone  = ax.artists[1]
boxone.set_facecolor('green')
boxone.set_edgecolor('black')
plt.show()

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=df)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=df)
plt.show()

# %%
sns.pairplot(df,hue ='Species')

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(df.corr(),annot = True,cmap = 'cubehelix',linewidths = 1
                 ,linecolor = 'k',square = True,mask = False,vmin = -1,vmax = 1,
                 cbar_kws = {"orientation": "vertical"},cbar = True)

# %%
df.hist(edgecolor = 'black',linewidth = 1.2)
fig = plt.gcf()
fig.set_size_inches(10,10)

# %%
sns.set(style="darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
fog = sns.swarmplot(x='Species',y = 'PetalLengthCm',data = df)

# %%
sns.set(style="darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(x="Species", y="PetalLengthCm",data = df,whis = np.inf)
fig = sns.swarmplot(x="Species", y="PetalLengthCm",data = df,color = '.2')

# %%
sns.set(style="darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(x="Species", y="PetalLengthCm",data = df,inner = None)
fig = sns.swarmplot(x="Species", y="PetalLengthCm",data = df,color = '.9')

# %%
sns.set(style = 'darkgrid')
sc = df[df.Species == 'Iris-setosa'].plot(kind = 'scatter',x = 'SepalLengthCm',y = 'SepalWidthCm'
                                         ,color = 'red',label = 'setosa')
df[df.Species == 'Iris-versicolor'].plot(kind = 'scatter',x = 'SepalLengthCm',y = 'SepalWidthCm'
                                         ,color = 'green',label = 'versicolor',ax = sc)
df[df.Species == 'Iris-virginica'].plot(kind = 'scatter',x = 'SepalLengthCm',y = 'SepalWidthCm'
                                         ,color = 'blue',label = 'virginica',ax = sc)
sc.set_xlabel('Sepal length in Cm')
sc.set_ylabel('Sepal width in Cm')
sc.set_title('Sepal length Vs Sepal width' )
sc = plt.gcf()
sc.set_size_inches(10,7)

# %%
fig = sns.lmplot(x = 'PetalLengthCm',y = 'PetalWidthCm',data = df)

# %%
sns.FacetGrid(df, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
plt.ioff()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X = df.drop(['Id', 'Species'], axis=1)
y = df["Species"]

# %% [markdown]
# # Modelling With Scikit Learn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y)

# %% [markdown]
# # K nearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
kn.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_test
# Out:
# 10         Iris-setosa
# 88     Iris-versicolor
# 123     Iris-virginica
# 140     Iris-virginica
# 83     Iris-versicolor
# 67     Iris-versicolor
# 46         Iris-setosa
# 135     Iris-virginica
# 43         Iris-setosa
# 38         Iris-setosa
# 68     Iris-versicolor
# 94     Iris-versicolor
# 97     Iris-versicolor
# 144     Iris-virginica
# 12         Iris-setosa
# 63     Iris-versicolor
# 66     Iris-versicolor
# 118     Iris-virginica
# 40         Iris-setosa
# 142     Iris-virginica
# 138     Iris-virginica
# 107     Iris-virginica
# 18         Iris-setosa
# 11         Iris-setosa
# 101     Iris-virginica
# 80     Iris-versicolor
# 54     Iris-versicolor
# 0          Iris-setosa
# 53     Iris-versicolor
# 4          Iris-setosa
# 16         Iris-setosa
# 51     Iris-versicolor
# 86     Iris-versicolor
# 2          Iris-setosa
# 131     Iris-virginica
# 89     Iris-versicolor
# 57     Iris-versicolor
# 7          Iris-setosa
# Name: Species, dtype: object

# %%
lr.predict(x_test.iloc[[1]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
from sklearn import metrics
y_pred = lr.predict(x_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9736842105263158

# %%
df.head(200)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
testt = np.array([6.5,3.3,5.9,2.6])
lr.predict([testt])
# Out:
# array(['Iris-virginica'], dtype=object)
